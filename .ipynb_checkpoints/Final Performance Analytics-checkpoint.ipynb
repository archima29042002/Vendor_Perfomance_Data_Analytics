# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
import warnings
import sqlite3
# from scipy.stats import ttest_ind
# import scipy.stats as stats
# warnings.fliterwarning('ignore')

# %% [markdown]
# Loading the Dataset

# %%
# creating database connection
conn = sqlite3.connect('inventory.db')

# fetching vendor summary data
df = pd.read_sql_query("select * from vendor_sales_summary", conn)
df.head()
# Out:
#    VendorNumber                VendorName  Brand                Description  \
# 0           480           BACARDI USA INC   4227  Bacardi Superior Rum Trav
# 1           480           BACARDI USA INC   3858           Grey Goose Vodka
# 2         12546   JIM BEAM BRANDS COMPANY   1476          Jim Beam Traveler
# 3          4425     MARTIGNETTI COMPANIES   3405      Tito's Handmade Vodka
# 4          3960  DIAGEO NORTH AMERICA INC   4261     Capt Morgan Spiced Rum
#
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          14.17        17.99  1750.0                   4906
# 1          17.77        23.99   750.0                   3202
# 2          16.05        21.99  1750.0                   2550
# 3          23.19        28.99  1750.0                    997
# 4          16.17        22.99  1750.0                   1241
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# 0              69518.02                 0.0               0.00
# 1              56899.54                 0.0               0.00
# 2              40927.50                41.0             901.59
# 3              23120.43                76.0            2279.24
# 4              20066.97                 0.0               0.00
#
#    TotalSalesPrice  TotalExciseTax  FreightCost  GrossProfit  ProfitMargin  \
# 0             0.00            0.00     89286.27    -69518.02          -inf
# 1             0.00            0.00     89286.27    -56899.54          -inf
# 2           285.87           75.34    123880.97    -40025.91  -4439.480252
# 3           569.81          139.62    144929.24    -20841.19   -914.392078
# 4             0.00            0.00    257032.07    -20066.97          -inf
#
#    StockTurnover  SalestoPurchaseRatio
# 0       0.000000              0.000000
# 1       0.000000              0.000000
# 2       0.016078              0.022029
# 3       0.076229              0.098581
# 4       0.000000              0.000000
